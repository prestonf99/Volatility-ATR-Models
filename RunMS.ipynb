# %%
import MorningStats as ms

# %% [markdown]
# You can adjust the days to load, the ATR will always come out the same way, but if you want to see a longer time series of the VRP, just increase the first number.

# %% [markdown]
# **_Available Tickers_**

# %%
sp = ms.Vols(360, '^GSPC')  # (days_to_load, S&P)
nq = ms.Vols(500, '^NDX')   # Nasdaq 100
rut = ms.Vols(500, '^RUT')  # Russell 2000
dji = ms.Vols(500, '^DJI')  # Dow Jones
cl = ms.Vols(500, 'CL=F')   # Crude Oil
gld = ms.Vols(500, 'GLD')   # Gold
aapl = ms.Vols(500, 'AAPL') # Apple
amzn = ms.Vols(500, 'AMZN') # Amazon
eem = ms.Vols(500, 'EEM')   # Emerging Markets
gs = ms.Vols(500, 'GS')     # Goldman Sachs
goog = ms.Vols(500, 'GOOG') # Google

# %% [markdown]
# ### Average Trading Range

# %%
sp.atr()

# %% [markdown]
# ### Close-Close Volatility Estimator
#
# * Calculates realized volatility using the closing price only.

# %%
nq.cc()

# %%
cl.ccs()

# %%
gs.vol_spread()

# %% [markdown]
# ### Yang-Zhang Volatility Estimator
#
# * Accounts for the OHLC volatility and the overnight.

# %%
aapl.plot_yz()
# Out:
# 2024-12-11 1.2333411539895103

# %%
amzn.plot_yzs()

# %%
goog.vol_spread_yz()
