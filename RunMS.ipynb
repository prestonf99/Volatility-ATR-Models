# %%
import MorningStats as ms

# %% [markdown]
# You can adjust the days to load, the ATR will always come out the same way, but if you want to see a longer time series of the VRP, just increase the first number. It currently only supports S&P(^GSPC) & Nasdaq.

# %% [markdown]
# **_Available Tickers_**

# %%
sp = ms.Vols(360, '^GSPC')  # (days_to_load, S&P)
nq = ms.Vols(360, '^NDX')   # Nasdaq 100
rut = ms.Vols(360, '^RUT')  # Russell 2000
dji = ms.Vols(360, '^DJI')  # Dow Jones
cl = ms.Vols(360, 'CL=F')   # Crude Oil
gld = ms.Vols(360, 'GLD')   # Gold
aapl = ms.Vols(360, 'AAPL') # Apple
amzn = ms.Vols(360, 'AMZN') # Amazon
eem = ms.Vols(360, 'EEM')   # Emerging Markets
gs = ms.Vols(360, 'GS')     # Goldman Sachs
goog = ms.Vols(360, 'GOOG') # Google

# %% [markdown]
# ### Average Trading Range

# %%
sp.atr()

# %% [markdown]
# ### Close-Close Volatility Estimator
#
# * Calculates realized volatility using the closing price only.

# %%
nq.cc()

# %%
cl.ccs()

# %%
gld.vol_spread()

# %% [markdown]
# ### Yang-Zhang Volatility Estimator
#
# * Accounts for the OHLC volatility and the overnight.

# %%
aapl.plot_yz()

# %%
amzn.plot_yzs()

# %%
goog.vol_spread_yz()
